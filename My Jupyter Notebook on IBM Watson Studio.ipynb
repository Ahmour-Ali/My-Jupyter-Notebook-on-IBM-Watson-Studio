# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ahmour Ali**
# <br>Data Scientist

# %% [markdown]
# *I am interested in data science because I am already doing data analyses in my current job but only in Excel. Learning Data Science by IBM through Coursera would enhance my Data Science skills which would be conducive for my current job as well as open doors for new job opportunities*

# %% [markdown]
# ### Following code will show simple addition of two numbers

# %%
2+2
# Out:
# 4

# %% [markdown]
# - One
# - Two
# - Three

# %% [markdown]
# 1. One
# 1. Two
# 1. Three

# %% [markdown]
# ***

# %% [markdown]
# <strike>strike through</strike>
